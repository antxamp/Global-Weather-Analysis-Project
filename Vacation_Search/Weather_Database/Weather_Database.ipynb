# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 758

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4c3237a5d3810ea714b644930e53e5a7

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
         
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        current_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": current_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")

print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | turbat
# Processing Record 3 of Set 1 | inta
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | saint george
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | high rock
# Processing Record 8 of Set 1 | tigil
# Processing Record 9 of Set 1 | saskylakh
# Processing Record 10 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | norman wells
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | lastoursville
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | iqaluit
# Processing Record 22 of Set 1 | brae
# Processing Record 23 of Set 1 | dikson
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | new norfolk
# Processing Record 27 of Set 1 | opuwo
# Processing Record 28 of Set 1 | meulaboh
# Processing Record 29 of Set 1 | trincomalee
# Processing Record 30 of Set 1 | longyearbyen
# Processing Record 31 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 1 | yining
# Processing Record 33 of Set 1 | severo-kurilsk
# Processing Record 34 of Set 1 | kingsville
# Processing Record 35 of Set 1 | bredasdorp
# Processing Record 36 of Set 1 | poum
# Processing Record 37 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 1 | matamoros
# Processing Record 39 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 1 | pisco
# Processing Record 41 of Set 1 | ilulissat
# Processing Record 42 of Set 1 | cidreira
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | port macquarie
# Processing Record 45 of Set 1 | geraldton
# Processing Record 46 of Set 1 | rio brilhante
# Processing Record 47 of Set 1 | saint-philippe
# Processing Record 48 of Set 1 | souillac
# Processing Record 49 of Set 1 | margate
# Processing Record 50 of Set 1 | arraial do cabo
# Processing Record 1 of Set 2 | havoysund
# Processing Record 2 of Set 2 | meiganga
# Processing Record 3 of Set 2 | alofi
# Processing Record 4 of Set 2 | batemans bay
# Processing Record 5 of Set 2 | rio grande
# Processing Record 6 of Set 2 | fairbanks
# Processing Record 7 of Set 2 | mar del plata
# Processing Record 8 of Set 2 | perth
# Processing Record 9 of Set 2 | sept-iles
# Processing Record 10 of Set 2 | hithadhoo
# Processing Record 11 of Set 2 | palmer
# Processing Record 12 of Set 2 | bambous virieux
# Processing Record 13 of Set 2 | jieshi
# Processing Record 14 of Set 2 | barrow
# Processing Record 15 of Set 2 | mahebourg
# Processing Record 16 of Set 2 | laguna
# Processing Record 17 of Set 2 | khatanga
# Processing Record 18 of Set 2 | nemuro
# Processing Record 19 of Set 2 | port alfred
# Processing Record 20 of Set 2 | carnarvon
# Processing Record 21 of Set 2 | soubre
# Processing Record 22 of Set 2 | chokurdakh
# Processing Record 23 of Set 2 | hamilton
# Processing Record 24 of Set 2 | inyonga
# Processing Record 25 of Set 2 | alice springs
# Processing Record 26 of Set 2 | punta arenas
# Processing Record 27 of Set 2 | saint anthony
# Processing Record 28 of Set 2 | port elizabeth
# Processing Record 29 of Set 2 | provideniya
# Processing Record 30 of Set 2 | kortkeros
# Processing Record 31 of Set 2 | bluff
# Processing Record 32 of Set 2 | castro
# Processing Record 33 of Set 2 | buala
# Processing Record 34 of Set 2 | nome
# Processing Record 35 of Set 2 | vanimo
# Processing Record 36 of Set 2 | olinda
# Processing Record 37 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 2 | luderitz
# Processing Record 39 of Set 2 | mount gambier
# Processing Record 40 of Set 2 | hasaki
# Processing Record 41 of Set 2 | mayumba
# Processing Record 42 of Set 2 | ust-kuyga
# Processing Record 43 of Set 2 | mangaldai
# Processing Record 44 of Set 2 | lagoa
# Processing Record 45 of Set 2 | sosnytsya
# Processing Record 46 of Set 2 | san quintin
# Processing Record 47 of Set 2 | grand gaube
# Processing Record 48 of Set 2 | ponta do sol
# Processing Record 49 of Set 2 | glarus
# Processing Record 50 of Set 2 | mataura
# Processing Record 1 of Set 3 | paramonga
# Processing Record 2 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 3 | bilibino
# Processing Record 4 of Set 3 | hermanus
# Processing Record 5 of Set 3 | upernavik
# Processing Record 6 of Set 3 | prijepolje
# Processing Record 7 of Set 3 | jasper
# Processing Record 8 of Set 3 | havre-saint-pierre
# Processing Record 9 of Set 3 | nicoya
# Processing Record 10 of Set 3 | sambava
# Processing Record 11 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 3 | kavaratti
# Processing Record 13 of Set 3 | atambua
# Processing Record 14 of Set 3 | jumilla
# Processing Record 15 of Set 3 | porto velho
# Processing Record 16 of Set 3 | eureka
# Processing Record 17 of Set 3 | buraydah
# Processing Record 18 of Set 3 | bethel
# Processing Record 19 of Set 3 | constitucion
# Processing Record 20 of Set 3 | katherine
# Processing Record 21 of Set 3 | nikolskoye
# Processing Record 22 of Set 3 | tasiilaq
# Processing Record 23 of Set 3 | jinzhou
# Processing Record 24 of Set 3 | chapais
# Processing Record 25 of Set 3 | thompson
# Processing Record 26 of Set 3 | pevek
# Processing Record 27 of Set 3 | sant julia de loria
# Processing Record 28 of Set 3 | santo antonio do sudoeste
# Processing Record 29 of Set 3 | necochea
# Processing Record 30 of Set 3 | kalmunai
# Processing Record 31 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 3 | sakakah
# Processing Record 33 of Set 3 | dalgopol
# Processing Record 34 of Set 3 | looc
# Processing Record 35 of Set 3 | abingdon
# Processing Record 36 of Set 3 | vila
# Processing Record 37 of Set 3 | avarua
# Processing Record 38 of Set 3 | broome
# Processing Record 39 of Set 3 | kaeo
# Processing Record 40 of Set 3 | fort nelson
# Processing Record 41 of Set 3 | atar
# Processing Record 42 of Set 3 | santa cruz
# Processing Record 43 of Set 3 | martil
# Processing Record 44 of Set 3 | chiang rai
# Processing Record 45 of Set 3 | agirish
# Processing Record 46 of Set 3 | ostrovnoy
# Processing Record 47 of Set 3 | dolbeau
# City not found. Skipping...
# Processing Record 48 of Set 3 | lebu
# Processing Record 49 of Set 3 | henties bay
# Processing Record 50 of Set 3 | prince rupert
# Processing Record 1 of Set 4 | chunhuhub
# Processing Record 2 of Set 4 | san patricio
# Processing Record 3 of Set 4 | georgetown
# Processing Record 4 of Set 4 | vung tau
# Processing Record 5 of Set 4 | dingle
# Processing Record 6 of Set 4 | yeppoon
# Processing Record 7 of Set 4 | kapit
# Processing Record 8 of Set 4 | hanyang
# Processing Record 9 of Set 4 | kodiak
# Processing Record 10 of Set 4 | burnie
# Processing Record 11 of Set 4 | limbang
# Processing Record 12 of Set 4 | torbay
# Processing Record 13 of Set 4 | karratha
# Processing Record 14 of Set 4 | khani
# Processing Record 15 of Set 4 | kilindoni
# Processing Record 16 of Set 4 | denau
# City not found. Skipping...
# Processing Record 17 of Set 4 | capinopolis
# Processing Record 18 of Set 4 | santa cruz de la palma
# Processing Record 19 of Set 4 | sistranda
# Processing Record 20 of Set 4 | dryden
# Processing Record 21 of Set 4 | rorvik
# Processing Record 22 of Set 4 | dawei
# Processing Record 23 of Set 4 | arlit
# Processing Record 24 of Set 4 | nurota
# Processing Record 25 of Set 4 | solnechnyy
# Processing Record 26 of Set 4 | chernushka
# Processing Record 27 of Set 4 | nantucket
# Processing Record 28 of Set 4 | kemijarvi
# Processing Record 29 of Set 4 | totness
# Processing Record 30 of Set 4 | aksarka
# Processing Record 31 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 4 | mikuni
# Processing Record 33 of Set 4 | klyuchi
# Processing Record 34 of Set 4 | carroll
# Processing Record 35 of Set 4 | vanavara
# Processing Record 36 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 4 | niimi
# Processing Record 39 of Set 4 | trairi
# Processing Record 40 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 41 of Set 4 | lorengau
# Processing Record 42 of Set 4 | guerrero negro
# Processing Record 43 of Set 4 | dese
# Processing Record 44 of Set 4 | esperance
# Processing Record 45 of Set 4 | hambantota
# Processing Record 46 of Set 4 | patiya
# Processing Record 47 of Set 4 | bengkulu
# Processing Record 48 of Set 4 | zhigansk
# Processing Record 49 of Set 4 | ekhabi
# Processing Record 50 of Set 4 | naze
# Processing Record 1 of Set 5 | pecos
# Processing Record 2 of Set 5 | east london
# Processing Record 3 of Set 5 | gushikawa
# Processing Record 4 of Set 5 | vila franca do campo
# Processing Record 5 of Set 5 | veraval
# Processing Record 6 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 5 | price
# Processing Record 9 of Set 5 | gat
# Processing Record 10 of Set 5 | shimoda
# Processing Record 11 of Set 5 | casper
# Processing Record 12 of Set 5 | bathsheba
# Processing Record 13 of Set 5 | vestmannaeyjar
# Processing Record 14 of Set 5 | hofn
# Processing Record 15 of Set 5 | lagunas
# Processing Record 16 of Set 5 | walvis bay
# Processing Record 17 of Set 5 | bacolod
# Processing Record 18 of Set 5 | tutoia
# Processing Record 19 of Set 5 | miresu mare
# Processing Record 20 of Set 5 | san-pedro
# Processing Record 21 of Set 5 | kloulklubed
# Processing Record 22 of Set 5 | tazovskiy
# Processing Record 23 of Set 5 | matipo
# Processing Record 24 of Set 5 | vagur
# Processing Record 25 of Set 5 | kahului
# Processing Record 26 of Set 5 | mehamn
# Processing Record 27 of Set 5 | klaksvik
# Processing Record 28 of Set 5 | doka
# Processing Record 29 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 5 | tala
# Processing Record 31 of Set 5 | victoria
# Processing Record 32 of Set 5 | mala
# Processing Record 33 of Set 5 | hobyo
# Processing Record 34 of Set 5 | shchelyayur
# City not found. Skipping...
# Processing Record 35 of Set 5 | chuy
# Processing Record 36 of Set 5 | nola
# Processing Record 37 of Set 5 | moravsky beroun
# Processing Record 38 of Set 5 | sao filipe
# Processing Record 39 of Set 5 | sangar
# Processing Record 40 of Set 5 | rawson
# Processing Record 41 of Set 5 | terney
# Processing Record 42 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 5 | whitehorse
# Processing Record 44 of Set 5 | singkang
# Processing Record 45 of Set 5 | amnat charoen
# Processing Record 46 of Set 5 | dalby
# Processing Record 47 of Set 5 | cheuskiny
# City not found. Skipping...
# Processing Record 48 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 5 | rantepao
# Processing Record 50 of Set 5 | zaysan
# Processing Record 1 of Set 6 | mayor pablo lagerenza
# Processing Record 2 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 3 of Set 6 | horta
# Processing Record 4 of Set 6 | dudinka
# Processing Record 5 of Set 6 | gizo
# Processing Record 6 of Set 6 | pangnirtung
# Processing Record 7 of Set 6 | kungurtug
# Processing Record 8 of Set 6 | faanui
# Processing Record 9 of Set 6 | akdepe
# Processing Record 10 of Set 6 | ozgon
# City not found. Skipping...
# Processing Record 11 of Set 6 | noumea
# Processing Record 12 of Set 6 | svetlogorsk
# Processing Record 13 of Set 6 | rayong
# Processing Record 14 of Set 6 | udachnyy
# Processing Record 15 of Set 6 | puerto ayora
# Processing Record 16 of Set 6 | bonthe
# Processing Record 17 of Set 6 | codrington
# Processing Record 18 of Set 6 | karakol
# Processing Record 19 of Set 6 | stodolishche
# Processing Record 20 of Set 6 | kyzyl-suu
# Processing Record 21 of Set 6 | cordoba
# Processing Record 22 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 23 of Set 6 | cayenne
# Processing Record 24 of Set 6 | prieska
# Processing Record 25 of Set 6 | evensk
# Processing Record 26 of Set 6 | tuatapere
# Processing Record 27 of Set 6 | san policarpo
# Processing Record 28 of Set 6 | beroroha
# Processing Record 29 of Set 6 | los andes
# Processing Record 30 of Set 6 | saint-francois
# Processing Record 31 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 6 | cherskiy
# Processing Record 33 of Set 6 | ayan
# Processing Record 34 of Set 6 | alamosa
# Processing Record 35 of Set 6 | bowen
# Processing Record 36 of Set 6 | warrington
# Processing Record 37 of Set 6 | ancud
# Processing Record 38 of Set 6 | satipo
# Processing Record 39 of Set 6 | morant bay
# Processing Record 40 of Set 6 | abu dhabi
# Processing Record 41 of Set 6 | namyslow
# Processing Record 42 of Set 6 | manokwari
# Processing Record 43 of Set 6 | oro valley
# Processing Record 44 of Set 6 | chitral
# Processing Record 45 of Set 6 | kruisfontein
# Processing Record 46 of Set 6 | pitimbu
# Processing Record 47 of Set 6 | bardiyah
# Processing Record 48 of Set 6 | ferrol
# Processing Record 49 of Set 6 | hay river
# Processing Record 50 of Set 6 | grindavik
# Processing Record 1 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 7 | waipawa
# Processing Record 3 of Set 7 | tautira
# Processing Record 4 of Set 7 | tromso
# Processing Record 5 of Set 7 | agadez
# Processing Record 6 of Set 7 | lasa
# Processing Record 7 of Set 7 | rio de janeiro
# Processing Record 8 of Set 7 | key west
# Processing Record 9 of Set 7 | soure
# Processing Record 10 of Set 7 | kaitangata
# Processing Record 11 of Set 7 | tayginka
# Processing Record 12 of Set 7 | vostok
# Processing Record 13 of Set 7 | cabo san lucas
# Processing Record 14 of Set 7 | taft
# Processing Record 15 of Set 7 | wanning
# Processing Record 16 of Set 7 | northam
# Processing Record 17 of Set 7 | talcahuano
# Processing Record 18 of Set 7 | chicama
# Processing Record 19 of Set 7 | bolitoc
# Processing Record 20 of Set 7 | caborca
# Processing Record 21 of Set 7 | redmond
# Processing Record 22 of Set 7 | lavrentiya
# Processing Record 23 of Set 7 | the valley
# Processing Record 24 of Set 7 | bhag
# Processing Record 25 of Set 7 | ngunguru
# Processing Record 26 of Set 7 | aksu
# Processing Record 27 of Set 7 | catuday
# Processing Record 28 of Set 7 | tuktoyaktuk
# Processing Record 29 of Set 7 | goderich
# Processing Record 30 of Set 7 | rio gallegos
# Processing Record 31 of Set 7 | orange
# Processing Record 32 of Set 7 | muros
# Processing Record 33 of Set 7 | oktyabrskiy
# Processing Record 34 of Set 7 | wampusirpi
# City not found. Skipping...
# Processing Record 35 of Set 7 | belmonte
# Processing Record 36 of Set 7 | beloha
# Processing Record 37 of Set 7 | lompoc
# Processing Record 38 of Set 7 | mareeba
# Processing Record 39 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 7 | fortuna
# Processing Record 41 of Set 7 | hualmay
# Processing Record 42 of Set 7 | nanortalik
# Processing Record 43 of Set 7 | mundgod
# Processing Record 44 of Set 7 | moree
# Processing Record 45 of Set 7 | moose factory
# Processing Record 46 of Set 7 | batagay
# Processing Record 47 of Set 7 | andarab
# City not found. Skipping...
# Processing Record 48 of Set 7 | nagato
# Processing Record 49 of Set 7 | ucluelet
# Processing Record 50 of Set 7 | moron
# Processing Record 1 of Set 8 | cap malheureux
# Processing Record 2 of Set 8 | marzuq
# Processing Record 3 of Set 8 | santa rosa
# Processing Record 4 of Set 8 | jalu
# Processing Record 5 of Set 8 | tarpon springs
# Processing Record 6 of Set 8 | kasongo-lunda
# Processing Record 7 of Set 8 | palu
# Processing Record 8 of Set 8 | lamar
# Processing Record 9 of Set 8 | barillas
# Processing Record 10 of Set 8 | comodoro rivadavia
# Processing Record 11 of Set 8 | buenavista
# Processing Record 12 of Set 8 | kelo
# Processing Record 13 of Set 8 | saldanha
# Processing Record 14 of Set 8 | praya
# Processing Record 15 of Set 8 | port moresby
# Processing Record 16 of Set 8 | praia da vitoria
# Processing Record 17 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 18 of Set 8 | yumen
# Processing Record 19 of Set 8 | namibe
# Processing Record 20 of Set 8 | road town
# Processing Record 21 of Set 8 | quatre cocos
# Processing Record 22 of Set 8 | barcelos
# Processing Record 23 of Set 8 | tiksi
# Processing Record 24 of Set 8 | mount isa
# Processing Record 25 of Set 8 | bunol
# Processing Record 26 of Set 8 | lac-megantic
# Processing Record 27 of Set 8 | olavarria
# Processing Record 28 of Set 8 | flinders
# Processing Record 29 of Set 8 | tete
# Processing Record 30 of Set 8 | egvekinot
# Processing Record 31 of Set 8 | amahai
# Processing Record 32 of Set 8 | martan-chu
# Processing Record 33 of Set 8 | husavik
# Processing Record 34 of Set 8 | ballitoville
# Processing Record 35 of Set 8 | chara
# Processing Record 36 of Set 8 | yabrud
# Processing Record 37 of Set 8 | college
# Processing Record 38 of Set 8 | rocha
# Processing Record 39 of Set 8 | narsaq
# Processing Record 40 of Set 8 | kedrovyy
# Processing Record 41 of Set 8 | gamboula
# Processing Record 42 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 8 | prince george
# Processing Record 44 of Set 8 | gamba
# Processing Record 45 of Set 8 | port hardy
# Processing Record 46 of Set 8 | belyy yar
# Processing Record 47 of Set 8 | suyo
# Processing Record 48 of Set 8 | batouri
# Processing Record 49 of Set 8 | katsuura
# Processing Record 50 of Set 8 | isla mujeres
# Processing Record 1 of Set 9 | anna paulowna
# Processing Record 2 of Set 9 | sanming
# Processing Record 3 of Set 9 | puno
# Processing Record 4 of Set 9 | kaka
# Processing Record 5 of Set 9 | taylor
# Processing Record 6 of Set 9 | xining
# Processing Record 7 of Set 9 | nalut
# Processing Record 8 of Set 9 | baruun-urt
# Processing Record 9 of Set 9 | nishihara
# Processing Record 10 of Set 9 | beringovskiy
# Processing Record 11 of Set 9 | diamantino
# Processing Record 12 of Set 9 | yankton
# Processing Record 13 of Set 9 | bolobo
# Processing Record 14 of Set 9 | kirya
# Processing Record 15 of Set 9 | bara
# Processing Record 16 of Set 9 | orbetello
# Processing Record 17 of Set 9 | olafsvik
# Processing Record 18 of Set 9 | carballo
# Processing Record 19 of Set 9 | elko
# Processing Record 20 of Set 9 | lazaro cardenas
# Processing Record 21 of Set 9 | emirdag
# Processing Record 22 of Set 9 | mangrol
# Processing Record 23 of Set 9 | ewa beach
# Processing Record 24 of Set 9 | hailar
# Processing Record 25 of Set 9 | saint-pierre
# Processing Record 26 of Set 9 | leningradskiy
# Processing Record 27 of Set 9 | sokoni
# Processing Record 28 of Set 9 | kiunga
# Processing Record 29 of Set 9 | wanparti
# Processing Record 30 of Set 9 | cervo
# Processing Record 31 of Set 9 | avera
# Processing Record 32 of Set 9 | mastic beach
# Processing Record 33 of Set 9 | biltine
# Processing Record 34 of Set 9 | wangkui
# Processing Record 35 of Set 9 | birobidzhan
# Processing Record 36 of Set 9 | talnakh
# Processing Record 37 of Set 9 | batticaloa
# Processing Record 38 of Set 9 | menongue
# Processing Record 39 of Set 9 | valdivia
# Processing Record 40 of Set 9 | saratoga springs
# Processing Record 41 of Set 9 | yarke pole
# Processing Record 42 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 9 | ossora
# Processing Record 44 of Set 9 | yar-sale
# Processing Record 45 of Set 9 | mana
# Processing Record 46 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 9 | jumla
# Processing Record 48 of Set 9 | berlevag
# Processing Record 49 of Set 9 | bargarh
# Processing Record 50 of Set 9 | krasnoyarka
# Processing Record 1 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 2 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 3 of Set 10 | gweta
# Processing Record 4 of Set 10 | gumdag
# Processing Record 5 of Set 10 | vardo
# Processing Record 6 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 7 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 10 | geresk
# City not found. Skipping...
# Processing Record 9 of Set 10 | awjilah
# Processing Record 10 of Set 10 | daokou
# Processing Record 11 of Set 10 | aberdeen
# Processing Record 12 of Set 10 | trofors
# Processing Record 13 of Set 10 | palauig
# Processing Record 14 of Set 10 | itarema
# Processing Record 15 of Set 10 | carbonia
# Processing Record 16 of Set 10 | solenzo
# Processing Record 17 of Set 10 | santa isabel do rio negro
# Processing Record 18 of Set 10 | vokhtoga
# Processing Record 19 of Set 10 | carutapera
# Processing Record 20 of Set 10 | trapani
# Processing Record 21 of Set 10 | wamba
# Processing Record 22 of Set 10 | namatanai
# Processing Record 23 of Set 10 | clyde river
# Processing Record 24 of Set 10 | ati
# Processing Record 25 of Set 10 | sao joao da barra
# Processing Record 26 of Set 10 | sedro-woolley
# Processing Record 27 of Set 10 | bubaque
# Processing Record 28 of Set 10 | mujiayingzi
# Processing Record 29 of Set 10 | arauca
# Processing Record 30 of Set 10 | maturin
# Processing Record 31 of Set 10 | porbandar
# Processing Record 32 of Set 10 | ambilobe
# Processing Record 33 of Set 10 | sao miguel do araguaia
# Processing Record 34 of Set 10 | pacific grove
# Processing Record 35 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 36 of Set 10 | viru
# Processing Record 37 of Set 10 | calbuco
# Processing Record 38 of Set 10 | marshall
# Processing Record 39 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 40 of Set 10 | cutler
# Processing Record 41 of Set 10 | inirida
# Processing Record 42 of Set 10 | hammerfest
# Processing Record 43 of Set 10 | mayaposi
# City not found. Skipping...
# Processing Record 44 of Set 10 | ribeira grande
# Processing Record 45 of Set 10 | dodge city
# Processing Record 46 of Set 10 | saalfelden
# City not found. Skipping...
# Processing Record 47 of Set 10 | santa lucia
# Processing Record 48 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 49 of Set 10 | dobrinka
# Processing Record 50 of Set 10 | shudayag
# Processing Record 1 of Set 11 | ust-tarka
# Processing Record 2 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 3 of Set 11 | palembang
# Processing Record 4 of Set 11 | teguise
# Processing Record 5 of Set 11 | keshan
# City not found. Skipping...
# Processing Record 6 of Set 11 | iskateley
# Processing Record 7 of Set 11 | larnaca
# Processing Record 8 of Set 11 | yarmouth
# Processing Record 9 of Set 11 | quanzhou
# Processing Record 10 of Set 11 | sitka
# Processing Record 11 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 12 of Set 11 | san carlos
# Processing Record 13 of Set 11 | pedasi
# Processing Record 14 of Set 11 | shishou
# Processing Record 15 of Set 11 | matadi
# Processing Record 16 of Set 11 | agadir
# Processing Record 17 of Set 11 | kiama
# Processing Record 18 of Set 11 | sundsvall
# Processing Record 19 of Set 11 | omboue
# Processing Record 20 of Set 11 | nanakuli
# Processing Record 21 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 22 of Set 11 | khash
# Processing Record 23 of Set 11 | kamaishi
# Processing Record 24 of Set 11 | turayf
# Processing Record 25 of Set 11 | axim
# Processing Record 26 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 11 | paraiso
# Processing Record 28 of Set 11 | kavieng
# Processing Record 29 of Set 11 | hollabrunn
# Processing Record 30 of Set 11 | antofagasta
# Processing Record 31 of Set 11 | penzance
# Processing Record 32 of Set 11 | boguchany
# Processing Record 33 of Set 11 | srednekolymsk
# Processing Record 34 of Set 11 | tsaratanana
# Processing Record 35 of Set 11 | byron bay
# Processing Record 36 of Set 11 | ullapool
# Processing Record 37 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 38 of Set 11 | bairiki
# Processing Record 39 of Set 11 | baykit
# Processing Record 40 of Set 11 | igurusi
# Processing Record 41 of Set 11 | khandbari
# Processing Record 42 of Set 11 | bay roberts
# Processing Record 43 of Set 11 | te anau
# Processing Record 44 of Set 11 | nasice
# Processing Record 45 of Set 11 | san jeronimo
# Processing Record 46 of Set 11 | ramsgate
# Processing Record 47 of Set 11 | labuhan
# Processing Record 48 of Set 11 | westport
# Processing Record 49 of Set 11 | san cristobal
# Processing Record 50 of Set 11 | pundaguitan
# Processing Record 1 of Set 12 | broken hill
# Processing Record 2 of Set 12 | kenai
# Processing Record 3 of Set 12 | port hedland
# Processing Record 4 of Set 12 | sorochinsk
# Processing Record 5 of Set 12 | lakes entrance
# Processing Record 6 of Set 12 | myskhako
# Processing Record 7 of Set 12 | waingapu
# Processing Record 8 of Set 12 | okhotsk
# Processing Record 9 of Set 12 | buta
# Processing Record 10 of Set 12 | liberal
# Processing Record 11 of Set 12 | lumby
# Processing Record 12 of Set 12 | ixtapa
# Processing Record 13 of Set 12 | plettenberg bay
# Processing Record 14 of Set 12 | gusau
# Processing Record 15 of Set 12 | caravelas
# Processing Record 16 of Set 12 | otjiwarongo
# Processing Record 17 of Set 12 | koson
# Processing Record 18 of Set 12 | lai
# Processing Record 19 of Set 12 | sawtell
# Processing Record 20 of Set 12 | qaqortoq
# Processing Record 21 of Set 12 | kismayo
# Processing Record 22 of Set 12 | afanasyevo
# City not found. Skipping...
# Processing Record 23 of Set 12 | nabire
# Processing Record 24 of Set 12 | mvuma
# Processing Record 25 of Set 12 | bozhou
# Processing Record 26 of Set 12 | praia
# Processing Record 27 of Set 12 | marmaron
# City not found. Skipping...
# Processing Record 28 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 29 of Set 12 | camacha
# Processing Record 30 of Set 12 | guatire
# Processing Record 31 of Set 12 | tera
# Processing Record 32 of Set 12 | guilin
# Processing Record 33 of Set 12 | balkhash
# Processing Record 34 of Set 12 | mildura
# Processing Record 35 of Set 12 | deputatskiy
# Processing Record 36 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 37 of Set 12 | mus
# Processing Record 38 of Set 12 | padang
# Processing Record 39 of Set 12 | canton
# Processing Record 40 of Set 12 | diffa
# Processing Record 41 of Set 12 | harbour breton
# Processing Record 42 of Set 12 | huarmey
# Processing Record 43 of Set 12 | linhares
# Processing Record 44 of Set 12 | cartagena del chaira
# Processing Record 45 of Set 12 | asau
# Processing Record 46 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 47 of Set 12 | great bend
# Processing Record 48 of Set 12 | vista hermosa
# Processing Record 49 of Set 12 | kieta
# Processing Record 50 of Set 12 | astana
# Processing Record 1 of Set 13 | itoman
# Processing Record 2 of Set 13 | camana
# Processing Record 3 of Set 13 | steamboat springs
# Processing Record 4 of Set 13 | campoverde
# Processing Record 5 of Set 13 | bima
# Processing Record 6 of Set 13 | gorontalo
# Processing Record 7 of Set 13 | soe
# Processing Record 8 of Set 13 | kingsport
# Processing Record 9 of Set 13 | elmshorn
# Processing Record 10 of Set 13 | manta
# Processing Record 11 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 12 of Set 13 | steinkjer
# Processing Record 13 of Set 13 | la rioja
# Processing Record 14 of Set 13 | aykhal
# Processing Record 15 of Set 13 | biak
# Processing Record 16 of Set 13 | airai
# Processing Record 17 of Set 13 | kombissiri
# Processing Record 18 of Set 13 | yulara
# Processing Record 19 of Set 13 | opobo
# City not found. Skipping...
# Processing Record 20 of Set 13 | saint-georges
# Processing Record 21 of Set 13 | sumbe
# Processing Record 22 of Set 13 | armidale
# Processing Record 23 of Set 13 | huntington
# Processing Record 24 of Set 13 | salekhard
# Processing Record 25 of Set 13 | slave lake
# Processing Record 26 of Set 13 | condado
# Processing Record 27 of Set 13 | izumo
# Processing Record 28 of Set 13 | ventspils
# Processing Record 29 of Set 13 | yuzawa
# Processing Record 30 of Set 13 | tura
# Processing Record 31 of Set 13 | kulhudhuffushi
# Processing Record 32 of Set 13 | sungai besar
# Processing Record 33 of Set 13 | verkh-usugli
# Processing Record 34 of Set 13 | georgiyevka
# Processing Record 35 of Set 13 | mezen
# Processing Record 36 of Set 13 | warrnambool
# Processing Record 37 of Set 13 | homer
# Processing Record 38 of Set 13 | gazni
# City not found. Skipping...
# Processing Record 39 of Set 13 | jamiltepec
# Processing Record 40 of Set 13 | desna
# Processing Record 41 of Set 13 | toba
# Processing Record 42 of Set 13 | murgab
# Processing Record 43 of Set 13 | port-gentil
# Processing Record 44 of Set 13 | tilichiki
# Processing Record 45 of Set 13 | helsinki
# Processing Record 46 of Set 13 | ceres
# Processing Record 47 of Set 13 | utrecht
# Processing Record 48 of Set 13 | diego de almagro
# Processing Record 49 of Set 13 | rumoi
# Processing Record 50 of Set 13 | paita
# Processing Record 1 of Set 14 | samarai
# Processing Record 2 of Set 14 | tigzirt
# Processing Record 3 of Set 14 | makueni
# Processing Record 4 of Set 14 | cockburn town
# Processing Record 5 of Set 14 | nouadhibou
# Processing Record 6 of Set 14 | turukhansk
# Processing Record 7 of Set 14 | paka
# Processing Record 8 of Set 14 | mahajanga
# Processing Record 9 of Set 14 | pueblo
# Processing Record 10 of Set 14 | zaltan
# Processing Record 11 of Set 14 | huntsville
# Processing Record 12 of Set 14 | lata
# Processing Record 13 of Set 14 | baker city
# Processing Record 14 of Set 14 | sorong
# Processing Record 15 of Set 14 | jibuti
# Processing Record 16 of Set 14 | coahuayana
# Processing Record 17 of Set 14 | visnes
# Processing Record 18 of Set 14 | grimari
# City not found. Skipping...
# Processing Record 19 of Set 14 | acarau
# Processing Record 20 of Set 14 | kudahuvadhoo
# Processing Record 21 of Set 14 | nueva guinea
# Processing Record 22 of Set 14 | wajid
# Processing Record 23 of Set 14 | parkes
# Processing Record 24 of Set 14 | san andres
# Processing Record 25 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 26 of Set 14 | sompeta
# Processing Record 27 of Set 14 | beibei
# Processing Record 28 of Set 14 | altay
# Processing Record 29 of Set 14 | ginda
# Processing Record 30 of Set 14 | fort-shevchenko
# Processing Record 31 of Set 14 | ninghai
# Processing Record 32 of Set 14 | akdagmadeni
# Processing Record 33 of Set 14 | eldikan
# City not found. Skipping...
# Processing Record 34 of Set 14 | malakal
# Processing Record 35 of Set 14 | tubli
# Processing Record 36 of Set 14 | ust-nera
# Processing Record 37 of Set 14 | paragominas
# Processing Record 38 of Set 14 | covington
# Processing Record 39 of Set 14 | haines junction
# Processing Record 40 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 41 of Set 14 | tezu
# Processing Record 42 of Set 14 | vangaindrano
# Processing Record 43 of Set 14 | puerto escondido
# Processing Record 44 of Set 14 | bandar-e anzali
# Processing Record 45 of Set 14 | gigmoto
# Processing Record 46 of Set 14 | george
# Processing Record 47 of Set 14 | onda
# Processing Record 48 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 49 of Set 14 | enumclaw
# Processing Record 50 of Set 14 | luoyang
# Processing Record 1 of Set 15 | boshnyakovo
# Processing Record 2 of Set 15 | krasnyy kut
# Processing Record 3 of Set 15 | santa fe
# Processing Record 4 of Set 15 | korla
# Processing Record 5 of Set 15 | aswan
# Processing Record 6 of Set 15 | roebourne
# Processing Record 7 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 15 | buchanan
# Processing Record 9 of Set 15 | ballina
# Processing Record 10 of Set 15 | tyukhtet
# Processing Record 11 of Set 15 | abha
# Processing Record 12 of Set 15 | boatlaname
# City not found. Skipping...
# Processing Record 13 of Set 15 | conceicao do araguaia
# Processing Record 14 of Set 15 | rudbar
# Processing Record 15 of Set 15 | touros
# Processing Record 16 of Set 15 | pauini
# Processing Record 17 of Set 15 | knysna
# Processing Record 18 of Set 15 | arvika
# Processing Record 19 of Set 15 | motygino
# Processing Record 20 of Set 15 | charagua
# Processing Record 21 of Set 15 | urumqi
# Processing Record 22 of Set 15 | qandala
# Processing Record 23 of Set 15 | port blair
# Processing Record 24 of Set 15 | mon
# Processing Record 25 of Set 15 | dakar
# Processing Record 26 of Set 15 | denpasar
# Processing Record 27 of Set 15 | tagcatong
# Processing Record 28 of Set 15 | swan river
# Processing Record 29 of Set 15 | baturaja
# Processing Record 30 of Set 15 | keti bandar
# Processing Record 31 of Set 15 | waihi beach
# Processing Record 32 of Set 15 | portland
# Processing Record 33 of Set 15 | aklavik
# Processing Record 34 of Set 15 | dennery
# Processing Record 35 of Set 15 | xai-xai
# Processing Record 36 of Set 15 | den helder
# Processing Record 37 of Set 15 | dehloran
# Processing Record 38 of Set 15 | roros
# Processing Record 39 of Set 15 | kirakira
# Processing Record 40 of Set 15 | ladario
# Processing Record 41 of Set 15 | mbini
# Processing Record 42 of Set 15 | umm lajj
# Processing Record 43 of Set 15 | alta
# Processing Record 44 of Set 15 | kidal
# Processing Record 45 of Set 15 | salalah
# Processing Record 46 of Set 15 | hvolsvollur
# Processing Record 47 of Set 15 | chingirlau
# Processing Record 48 of Set 15 | harnosand
# Processing Record 49 of Set 15 | kerouane
# Processing Record 50 of Set 15 | policoro
# Processing Record 1 of Set 16 | komsomolskiy
# Processing Record 2 of Set 16 | bombay
# Processing Record 3 of Set 16 | isabela
# Processing Record 4 of Set 16 | qeshm
# Processing Record 5 of Set 16 | coatesville
# Processing Record 6 of Set 16 | tombouctou
# Processing Record 7 of Set 16 | stromness
# Processing Record 8 of Set 16 | fujin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Checking to see if dataframe is correct.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Atuona      PF  -9.8000 -139.0333     79.75        75          94
# 1        Turbat      PK  26.0023   63.0440     99.68        18          67
# 2          Inta      RU  66.0317   60.1659     31.12        88          98
# 3        Hobart      AU -42.8794  147.3294     57.20        67          75
# 4  Saint George      US  37.1041 -113.5841     53.60        50           1
# 5         Vaini      TO -21.2000 -175.2000     73.40        94          75
# 6     High Rock      BS  26.6208  -78.2833     64.40        88          20
# 7         Tigil      RU  57.8000  158.6667     29.71        93          70
# 8     Saskylakh      RU  71.9167  114.0833     33.57        86          80
# 9       Rikitea      PF -23.1203 -134.9692     76.33        73          71
#
#    Wind Speed Current Description
# 0       15.37          light rain
# 1        9.42       broken clouds
# 2        6.85     overcast clouds
# 3        5.75          light rain
# 4       10.36           clear sky
# 5        9.22       broken clouds
# 6        5.75          few clouds
# 7        7.09       broken clouds
# 8        7.67       broken clouds
# 9        9.95          light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
